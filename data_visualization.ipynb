# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("Dados.csv")
df.head()
# Out:
#   from   to  price week_day_search day_search part_of_day  flight_day comp
# 0  SAO  RIO    266             Tue   09/11/18       tarde  2018-09-30  NaN
# 1  SAO  RIO    266             Tue   09/11/18       tarde  2018-09-30  NaN
# 2  SAO  RIO    457             Tue   09/11/18       tarde  2018-09-30  NaN
# 3  SAO  RIO    470             Tue   09/11/18       tarde  2018-09-30  NaN
# 4  SAO  RIO    483             Tue   09/11/18       tarde  2018-09-30  NaN

# %%
df.shape
# Out:
# (2500, 8)

# %% [markdown]
# # Gráfico de distribuiçao dos preços das passagens
# este grafico apresenta a distribuição dos preços das passagens no formato de ponto, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.set_style('darkgrid')
sns.stripplot(x=df['week_day_search'],y=df['price'],hue = df['part_of_day'],palette='Set1')
axes.set_title("Distribuição do Preço das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})

# %% [markdown]
# # Gráfico BoxPlot dos preços das passagens
# este grafico apresenta a distribuição dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.boxplot(x=df['week_day_search'],y=df['price'],hue = df['part_of_day'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})

# %% [markdown]
# # Gráfico BarPlot dos preços das passagens
# este grafico apresenta a a média dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,550,25))
sns.barplot(x=df['week_day_search'],y=df['price'],hue = df['part_of_day'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})
# Out:
# /home/tomas/.pyenv/versions/3.6.0/envs/jupyter3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Gráfico ViolinPlot dos preços das passagens
# este grafico apresenta a a média dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.violinplot(x='week_day_search',y='price',data = df,hue = df['part_of_day'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})
# Out:
# /home/tomas/.pyenv/versions/3.6.0/envs/jupyter3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Gráfico de distribuiçao dos preços das passagens
# este grafico apresenta a distribuição dos preços das passagens no formato de ponto, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.stripplot(x=df['week_day_search'],y=df['price'],hue = df['comp'],palette='Set1')
axes.set_title("Distribuição do Preço das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})

# %% [markdown]
# # Gráfico BoxPlot dos preços das passagens
# este grafico apresenta a distribuição dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.boxplot(x=df['week_day_search'],y=df['price'],hue = df['comp'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})

# %% [markdown]
# # Gráfico BarPlot dos preços das passagens
# este grafico apresenta a a média dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,550,25))
sns.barplot(x=df['week_day_search'],y=df['price'],hue = df['comp'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})
# Out:
# /home/tomas/.pyenv/versions/3.6.0/envs/jupyter3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Gráfico ViolinPlot dos preços das passagens
# este grafico apresenta a a média dos preços das passagens no formato Boxplot, onde se há a distinção dos dias da semana na qual foi realizada a pesquisa e com separação da parte do dia tambem(se foi realizada de Manha, tarde,noite ou madrugada)

# %%
fig , axes = plt.subplots(figsize= (17,14))
plt.yticks(np.arange(0,3000,125))
sns.violinplot(x=df['week_day_search'],y=df['price'],hue = df['comp'],palette='Set1')
axes.set_title("Distribuição BoxPlot das Passagens")
axes.set_ylabel("Preço das Passagens")
axes.set_xlabel('Dia da semana em que a Pesquisa foi realizada')
axes.legend(prop={'size': 12})
# Out:
# /home/tomas/.pyenv/versions/3.6.0/envs/jupyter3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
